# %%
# make sure rpy2 is installed from pypi
from rpy2.robjects.packages import importr

# %%
rds_path = "" # Point to .rds filepath

# %%
base = importr('base')
seurat = importr('SeuratObject')

# %%
rds_object = base.readRDS(rds_path)

# %%
seurat.Version(object=rds_object)[0]
