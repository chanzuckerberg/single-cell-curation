# %% [markdown]
# # Fetch a Collection with full Dataset metadata

# %% [markdown]
# The script in this notebook fetches full Collection metadata for a given Collection.
#
# Fetching an individual Collection requires only the Collection id, and not an API key/access token.

# %% [markdown]
# ### Import dependencies

# %%
from src.collection import get_collection
from src.utils.config import set_api_access_config  # still required for setting api url env vars

# %% [markdown]
# #### <font color='#bc00b0'>Please fill in the required values:</font>

# %% [markdown]
# <font color='#bc00b0'>(Required) Enter the id of the Collection you want to fetch</font>
#
# _The Collection id can be found by looking at the url path in the address bar
# when viewing your Collection in the CZ CELLxGENE Discover data portal: `/collections/{collection_id}`._

# %%
collection_id = "e7dfe86d-0400-4f2e-95bb-1a906ff7283a"

# %% [markdown]
# ### Set url env vars

# %%
set_api_access_config()
# Out:
# Set 'SITE_URL' env var to https://cellxgene.cziscience.com
# Set 'API_URL_BASE' env var to https://api.cellxgene.cziscience.com
# No API key file provided. Without an access token, which requires an API key to retrieve, no private data or actions are accessible (except for fetching an individual Collection or Dataset, which only requires the url).

# %% [markdown]
# ### Fetch Collection

# %%
collection = get_collection(collection_id)
from pprint import pprint

pprint(collection)
# Out:
# No access token included in request
# {'collection_id': 'e7dfe86d-0400-4f2e-95bb-1a906ff7283a',
#  'collection_url': 'https://cellxgene.cziscience.com/collections/e7dfe86d-0400-4f2e-95bb-1a906ff7283a',
#  'collection_version_id': 'e7dfe86d-0400-4f2e-95bb-1a906ff7283a',
#  'consortia': ['BRAIN Initiative'],
#  'contact_email': 'kimberly.siletti@ki.se',
#  'contact_name': 'Kimberly Siletti',
#  'created_at': '2023-05-04T22:47:35.284875+00:00',
#  'curator_name': 'James Chaffer',
#  'datasets': [{'assay': [{'label': "10x 3' v3",
#                           'ontology_term_id': 'EFO:0009922'}],
#                'assets': [{'filesize': 339098252,
#                            'filetype': 'H5AD',
#                            'url': 'https://datasets.cellxgene.cziscience.com/b5e49df2-61a1-4f32-987e-f0854671fb86.h5ad'},
#                           {'filesize': 376685905,
#                            'filetype': 'RDS',
#                            'url': 'https://datasets.cellxgene.cziscience.com/b5e49df2-61a1-4f32-987e-f0854671fb86.rds'}],
#                'batch_condition': ['sample_id'],
#                'cell_count': 28051,
#                'cell_type': [{'label': 'astrocyte',
#                               'ontology_term_id': 'CL:0000127'},
#                              {'label': 'central nervous system macrophage',
#                               'ontology_term_id': 'CL:0000878'},
#                              {'label': 'endothelial cell',
#                               'ontology_term_id': 'CL:0000115'},
#                              {'label': 'fibroblast',
#                               'ontology_term_id': 'CL:0000057'},
#                              {'label': 'leukocyte',
#                               'ontology_term_id': 'CL:0000738'},
#                              {'label': 'neuron',
#                               'ontology_term_id': 'CL:0000540'},
#                              {'label': 'oligodendrocyte',
#                               'ontology_term_id': 'CL:0000128'},
#                              {'label': 'oligodendrocyte precursor cell',
#                               'ontology_term_id': 'CL:0002453'},
#                              {'label': 'pericyte',
#                               'ontology_term_id': 'CL:0000669'},
#                              {'label': 'vascular associated smooth muscle cell',
#                               'ontology_term_id': 'CL:0000359'}],
#                'dataset_id': 'ff7d15fa-f4b6-4a0e-992e-fd0c9d088ded',
#                'dataset_version_id': 'b5e49df2-61a1-4f32-987e-f0854671fb86',
#                'development_stage': [{'label': '29-year-old human stage',
#                                       'ontology_term_id': 'HsapDv:0000123'},
#                                      {'label': '42-year-old human stage',
#                                       'ontology_term_id': 'HsapDv:0000136'},
#                                      {'label': '50-year-old human stage',
#                                       'ontology_term_id': 'HsapDv:0000144'}],
#                'disease': [{'label': 'normal',
#                             'ontology_term_id': 'PATO:0000461'}],
#                'donor_id': ['H19.30.001', 'H18.30.002', 'H19.30.002'],
#                'explorer_url': 'https://cellxgene.cziscience.com/e/b5e49df2-61a1-4f32-987e-f0854671fb86.cxg/',
#                'is_primary_data': [True],
#                'mean_genes_per_cell': 5381.864425510677,
#                'organism': [{'label': 'Homo sapiens',
#                              'ontology_term_id': 'NCBITaxon:9606'}],
#                'processing_status': 'SUCCESS',
#                'published_at': '2022-12-09T18:17:51.942387+00:00',
#                'revised_at': '2023-04-20T16:43:41.279680+00:00',
#                'schema_version': '3.0.0',
#                'self_reported_ethnicity': [{'label': 'European',
#                                             'ontology_term_id': 'HANCESTRO:0005'}],
#                'sex': [{'label': 'male', 'ontology_term_id': 'PATO:0000384'}],
#                'suspension_type': ['nucleus'],
#                'tissue': [{'label': 'cerebral cortex',
#                            'ontology_term_id': 'UBERON:0000956'}],
#                'title': 'Dissection: Cerebral cortex (Cx) - Cuneus, rostral '
#                         'part - Area Prostriata - Pro',
#                'tombstone': False,
#                'x_approximate_distribution': None},
#               {'assay': [{'label': "10x 3' v3",
#                           'ontology_term_id': 'EFO:0009922'}],
#                'assets': [{'filesize': 390710860,
#                            'filetype': 'H5AD',
#                            'url': 'https://datasets.cellxgene.cziscience.com/b5a54868-e648-4d0f-a75a-ba279e058451.h5ad'},
#                           {'filesize': 435669581,
#                            'filetype': 'RDS',
#                            'url': 'https://datasets.cellxgene.cziscience.com/b5a54868-e648-4d0f-a75a-ba279e058451.rds'}],
#                'batch_condition': ['sample_id'],
#                'cell_count': 35285,
#                'cell_type': [{'label': 'astrocyte',
#                               'ontology_term_id': 'CL:0000127'},
#                              {'label': 'central nervous system macrophage',
#                               'ontology_term_id': 'CL:0000878'},
#                              {'label': 'endothelial cell',
#                               'ontology_term_id': 'CL:0000115'},
#                              {'label': 'ependymal cell',
#                               'ontology_term_id': 'CL:0000065'},
#                              {'label': 'fibroblast',
#                               'ontology_term_id': 'CL:0000057'},
#                              {'label': 'leukocyte',
#                               'ontology_term_id': 'CL:0000738'},
#                              {'label': 'neuron',
#                               'ontology_term_id': 'CL:0000540'},
#                              {'label': 'oligodendrocyte',
#                               'ontology_term_id': 'CL:0000128'},
#                              {'label': 'oligodendrocyte precursor cell',
#                               'ontology_term_id': 'CL:0002453'},
#                              {'label': 'pericyte',
#                               'ontology_term_id': 'CL:0000669'},
#                              {'label': 'vascular associated smooth muscle cell',
#                               'ontology_term_id': 'CL:0000359'}],
#                'dataset_id': 'fe1a73ab-a203-45fd-84e9-0f7fd19efcbd',
#                'dataset_version_id': 'b5a54868-e648-4d0f-a75a-ba279e058451',
#                'development_stage': [{'label': '29-year-old human stage',
#                                       'ontology_term_id': 'HsapDv:0000123'},
#                                      {'label': '42-year-old human stage',
#                                       'ontology_term_id': 'HsapDv:0000136'},
#                                      {'label': '50-year-old human stage',
#                                       'ontology_term_id': 'HsapDv:0000144'}],
#                'disease': [{'label': 'normal',
#                             'ontology_term_id': 'PATO:0000461'}],
#                'donor_id': ['H19.30.001', 'H18.30.002', 'H19.30.002'],
#                'explorer_url': 'https://cellxgene.cziscience.com/e/b5a54868-e648-4d0f-a75a-ba279e058451.cxg/',
#                'is_primary_data': [True],
#                'mean_genes_per_cell': 4818.551792546408,
#                'organism': [{'label': 'Homo sapiens',
#                              'ontology_term_id': 'NCBITaxon:9606'}],
#                'processing_status': 'SUCCESS',
#                'published_at': '2022-12-09T18:17:51.942387+00:00',
#                'revised_at': '2023-04-20T16:43:41.279680+00:00',
#                'schema_version': '3.0.0',
#                'self_reported_ethnicity': [{'label': 'European',
#                                             'ontology_term_id': 'HANCESTRO:0005'}],
#                'sex': [{'label': 'male', 'ontology_term_id': 'PATO:0000384'}],
#                'suspension_type': ['nucleus'],
#                'tissue': [{'label': 'cerebral nuclei',
#                            'ontology_term_id': 'UBERON:8440012'}],
#                'title': 'Dissection: Amygdaloid complex (AMY) - basolateral '
#                         'nuclear group (BLN) - basolateral nucleus (basal '
#                         'nucleus) - BL',
#                'tombstone': False,
#                'x_approximate_distribution': None},
#               {'assay': [{'label': "10x 3' v3",
#                           'ontology_term_id': 'EFO:0009922'}],
#                'assets': [{'filesize': 138639337,
#                            'filetype': 'H5AD',
#                            'url': 'https://datasets.cellxgene.cziscience.com/44a37128-d494-4c4a-9866-b75aed2fa8f0.h5ad'},
#                           {'filesize': 138466019,
#                            'filetype': 'RDS',
#                            'url': 'https://datasets.cellxgene.cziscience.com/44a37128-d494-4c4a-9866-b75aed2fa8f0.rds'}],
#                'batch_condition': ['sample_id'],
#                'cell_count': 17660,
#                'cell_type': [{'label': 'astrocyte',
#                               'ontology_term_id': 'CL:0000127'},
#                              {'label': 'central nervous system macrophage',
#                               'ontology_term_id': 'CL:0000878'},
#                              {'label': 'endothelial cell',
#                               'ontology_term_id': 'CL:0000115'},
#                              {'label': 'fibroblast',
#                               'ontology_term_id': 'CL:0000057'},
#                              {'label': 'leukocyte',
#                               'ontology_term_id': 'CL:0000738'},
#                              {'label': 'neuron',
#                               'ontology_term_id': 'CL:0000540'},
#                              {'label': 'oligodendrocyte',
#                               'ontology_term_id': 'CL:0000128'},
#                              {'label': 'oligodendrocyte precursor cell',
#                               'ontology_term_id': 'CL:0002453'},
#                              {'label': 'pericyte',
#                               'ontology_term_id': 'CL:0000669'},
#                              {'label': 'vascular associated smooth muscle cell',
#                               'ontology_term_id': 'CL:0000359'}],
#                'dataset_id': 'fbf173f9-f809-4d84-9b65-ae205d35b523',
#                'dataset_version_id': '44a37128-d494-4c4a-9866-b75aed2fa8f0',
#                'development_stage': [{'label': '50-year-old human stage',
#                                       'ontology_term_id': 'HsapDv:0000144'}],
#                'disease': [{'label': 'normal',
#                             'ontology_term_id': 'PATO:0000461'}],
#                'donor_id': ['H18.30.002'],
#                'explorer_url': 'https://cellxgene.cziscience.com/e/44a37128-d494-4c4a-9866-b75aed2fa8f0.cxg/',
#                'is_primary_data': [True],
#                'mean_genes_per_cell': 3199.6190826727066,
#                'organism': [{'label': 'Homo sapiens',
#                              'ontology_term_id': 'NCBITaxon:9606'}],
#                'processing_status': 'SUCCESS',
#                'published_at': '2022-12-09T18:17:51.942387+00:00',
#                'revised_at': '2023-04-20T16:43:41.279680+00:00',
#                'schema_version': '3.0.0',
#                'self_reported_ethnicity': [{'label': 'European',
#                                             'ontology_term_id': 'HANCESTRO:0005'}],
#                'sex': [{'label': 'male', 'ontology_term_id': 'PATO:0000384'}],
#                'suspension_type': ['nucleus'],
#                'tissue': [{'label': 'thalamic complex',
#                            'ontology_term_id': 'UBERON:0010225'}],
#                'title': 'Dissection: Thalamus (THM) - lateral nuclear complex '
#                         'of thalamus (LNC) - lateral posterior nucleus of '
#                         'thalamus + ventral posterior lateral nucleus - LP + '
#                         'VPL',
#                'tombstone': False,
#                'x_approximate_distribution': None},
#               {'assay': [{'label': "10x 3' v3",
#                           'ontology_term_id': 'EFO:0009922'}],
#                'assets': [{'filesize': 350600053,
#                            'filetype': 'H5AD',
#                            'url': 'https://datasets.cellxgene.cziscience.com/98c7233e-b57a-4548-a7e0-dd989984bd44.h5ad'},
#                           {'filesize': 382880596,
#                            'filetype': 'RDS',
#                            'url': 'https://datasets.cellxgene.cziscience.com/98c7233e-b57a-4548-a7e0-dd989984bd44.rds'}],
#                'batch_condition': ['sample_id'],
#                'cell_count': 29674,
#                'cell_type': [{'label': 'astrocyte',
#                               'ontology_term_id': 'CL:0000127'},
#                              {'label': 'central nervous system macrophage',
#                               'ontology_term_id': 'CL:0000878'},
#                              {'label': 'endothelial cell',
#                               'ontology_term_id': 'CL:0000115'},
#                              {'label': 'fibroblast',
#                               'ontology_term_id': 'CL:0000057'},
#                              {'label': 'leukocyte',
#                               'ontology_term_id': 'CL:0000738'},
#                              {'label': 'neuron',
#                               'ontology_term_id': 'CL:0000540'},
#                              {'label': 'oligodendrocyte',
#                               'ontology_term_id': 'CL:0000128'},
#                              {'label': 'oligodendrocyte precursor cell',
#                               'ontology_term_id': 'CL:0002453'},
#                              {'label': 'pericyte',
#                               'ontology_term_id': 'CL:0000669'},
#                              {'label': 'vascular associated smooth muscle cell',
#                               'ontology_term_id': 'CL:0000359'}],
#                'dataset_id': 'fa554686-fc07-44dd-b2de-b726d82d26ec',
#                'dataset_version_id': '98c7233e-b57a-4548-a7e0-dd989984bd44',
#                'development_stage': [{'label': '29-year-old human stage',
#                                       'ontology_term_id': 'HsapDv:0000123'},
#                                      {'label': '42-year-old human stage',
#                                       'ontology_term_id': 'HsapDv:0000136'},
#                                      {'label': '50-year-old human stage',
#                                       'ontology_term_id': 'HsapDv:0000144'}],
#                'disease': [{'label': 'normal',
#                             'ontology_term_id': 'PATO:0000461'}],
#                'donor_id': ['H19.30.002', 'H19.30.001', 'H18.30.002'],
#                'explorer_url': 'https://cellxgene.cziscience.com/e/98c7233e-b57a-4548-a7e0-dd989984bd44.cxg/',
#                'is_primary_data': [True],
#                'mean_genes_per_cell': 5237.493563388825,
#                'organism': [{'label': 'Homo sapiens',
#                              'ontology_term_id': 'NCBITaxon:9606'}],
#                'processing_status': 'SUCCESS',
#                'published_at': '2022-12-09T18:17:51.942387+00:00',
#                'revised_at': '2023-04-20T16:43:41.279680+00:00',
#                'schema_version': '3.0.0',
#                'self_reported_ethnicity': [{'label': 'European',
#                                             'ontology_term_id': 'HANCESTRO:0005'}],
#                'sex': [{'label': 'male', 'ontology_term_id': 'PATO:0000384'}],
#                'suspension_type': ['nucleus'],
#                'tissue': [{'label': 'cerebral cortex',
#                            'ontology_term_id': 'UBERON:0000956'}],
#                'title': 'Dissection: Cerebral cortex (Cx) - Superior occipital '
#                         'gyrus (SOG) - Areas 19 and MT - A19',
#                'tombstone': False,
#                'x_approximate_distribution': None},
#               {'assay': [{'label': "10x 3' v3",
#                           'ontology_term_id': 'EFO:0009922'}],
#                'assets': [{'filesize': 229925535,
#                            'filetype': 'H5AD',
#                            'url': 'https://datasets.cellxgene.cziscience.com/28fd1f58-c77f-4dd8-9793-04d9b298d927.h5ad'},
#                           {'filesize': 255967171,
#                            'filetype': 'RDS',
#                            'url': 'https://datasets.cellxgene.cziscience.com/28fd1f58-c77f-4dd8-9793-04d9b298d927.rds'}],
#                'batch_condition': ['sample_id'],
#                'cell_count': 23120,
#                'cell_type': [{'label': 'Bergmann glial cell',
#                               'ontology_term_id': 'CL:0000644'},
#                              {'label': 'astrocyte',
#                               'ontology_term_id': 'CL:0000127'},
#                              {'label': 'central nervous system macrophage',
#                               'ontology_term_id': 'CL:0000878'},
#                              {'label': 'choroid plexus epithelial cell',
#                               'ontology_term_id': 'CL:0000706'},
#                              {'label': 'endothelial cell',
#                               'ontology_term_id': 'CL:0000115'},
#                              {'label': 'ependymal cell',
#                               'ontology_term_id': 'CL:0000065'},
#                              {'label': 'fibroblast',
#                               'ontology_term_id': 'CL:0000057'},
#                              {'label': 'leukocyte',
#                               'ontology_term_id': 'CL:0000738'},
#                              {'label': 'neuron',
#                               'ontology_term_id': 'CL:0000540'},
#                              {'label': 'oligodendrocyte',
#                               'ontology_term_id': 'CL:0000128'},
#                              {'label': 'oligodendrocyte precursor cell',
#                               'ontology_term_id': 'CL:0002453'},
#                              {'label': 'pericyte',
#                               'ontology_term_id': 'CL:0000669'},
#                              {'label': 'vascular associated smooth muscle cell',
#                               'ontology_term_id': 'CL:0000359'}],
#                'dataset_id': 'f9034091-2e8f-4ac6-9874-e7b7eb566824',
#                'dataset_version_id': '28fd1f58-c77f-4dd8-9793-04d9b298d927',
#                'development_stage': [{'label': '42-year-old human stage',
#                                       'ontology_term_id': 'HsapDv:0000136'},
#                                      {'label': '50-year-old human stage',
#                                       'ontology_term_id': 'HsapDv:0000144'}],
#                'disease': [{'label': 'normal',
#                             'ontology_term_id': 'PATO:0000461'}],
#                'donor_id': ['H19.30.001', 'H18.30.002'],
#                'explorer_url': 'https://cellxgene.cziscience.com/e/28fd1f58-c77f-4dd8-9793-04d9b298d927.cxg/',
#                'is_primary_data': [True],
#                'mean_genes_per_cell': 4251.853243944636,
#                'organism': [{'label': 'Homo sapiens',
#                              'ontology_term_id': 'NCBITaxon:9606'}],
#                'processing_status': 'SUCCESS',
#                'published_at': '2022-12-09T18:17:51.942387+00:00',
#                'revised_at': '2023-04-20T16:43:41.279680+00:00',
#                'schema_version': '3.0.0',
#                'self_reported_ethnicity': [{'label': 'European',
#                                             'ontology_term_id': 'HANCESTRO:0005'}],
#                'sex': [{'label': 'male', 'ontology_term_id': 'PATO:0000384'}],
#                'suspension_type': ['nucleus'],
#                'tissue': [{'label': 'myelencephalon',
#                            'ontology_term_id': 'UBERON:0005290'}],
#                'title': 'Dissection: Myelencephalon (medulla oblongata) (Mo) - '
#                         'medullary reticular formation (MoRF) & efferent '
#                         'nuclei of cranial nerves in the medulla oblongata '
#                         '(MoEN) - MoRF-MoEN',
#                'tombstone': False,
#                'x_approximate_distribution': None},
#               {'assay': [{'label': "10x 3' v3",
#                           'ontology_term_id': 'EFO:0009922'}],
#                'assets': [{'filesize': 361678418,
#                            'filetype': 'H5AD',
#                            'url': 'https://datasets.cellxgene.cziscience.com/ffe867d4-f8a9-4a34-943f-edfffeec5b97.h5ad'},
#                           {'filesize': 401690948,
#                            'filetype': 'RDS',
#                            'url': 'https://datasets.cellxgene.cziscience.com/ffe867d4-f8a9-4a34-943f-edfffeec5b97.rds'}],
#                'batch_condition': ['sample_id'],
#                'cell_count': 31899,
#                'cell_type': [{'label': 'astrocyte',
#                               'ontology_term_id': 'CL:0000127'},
#                              {'label': 'central nervous system macrophage',
#                               'ontology_term_id': 'CL:0000878'},
#                              {'label': 'endothelial cell',
#                               'ontology_term_id': 'CL:0000115'},
#                              {'label': 'fibroblast',
#                               'ontology_term_id': 'CL:0000057'},
#                              {'label': 'leukocyte',
#                               'ontology_term_id': 'CL:0000738'},
#                              {'label': 'neuron',
#                               'ontology_term_id': 'CL:0000540'},
#                              {'label': 'oligodendrocyte',
#                               'ontology_term_id': 'CL:0000128'},
#                              {'label': 'oligodendrocyte precursor cell',
#                               'ontology_term_id': 'CL:0002453'},
#                              {'label': 'pericyte',
#                               'ontology_term_id': 'CL:0000669'},
#                              {'label': 'vascular associated smooth muscle cell',
#                               'ontology_term_id': 'CL:0000359'}],
#                'dataset_id': 'f8dda921-5fb4-4c94-a654-c6fc346bfd6d',
#                'dataset_version_id': 'ffe867d4-f8a9-4a34-943f-edfffeec5b97',
#                'development_stage': [{'label': '29-year-old human stage',
#                                       'ontology_term_id': 'HsapDv:0000123'},
#                                      {'label': '42-year-old human stage',
#                                       'ontology_term_id': 'HsapDv:0000136'},
#                                      {'label': '50-year-old human stage',
#                                       'ontology_term_id': 'HsapDv:0000144'}],
#                'disease': [{'label': 'normal',
#                             'ontology_term_id': 'PATO:0000461'}],
#                'donor_id': ['H19.30.001', 'H18.30.002', 'H19.30.002'],
#                'explorer_url': 'https://cellxgene.cziscience.com/e/ffe867d4-f8a9-4a34-943f-edfffeec5b97.cxg/',
#                'is_primary_data': [True],
#                'mean_genes_per_cell': 5049.990469920687,
#                'organism': [{'label': 'Homo sapiens',
#                              'ontology_term_id': 'NCBITaxon:9606'}],
#                'processing_status': 'SUCCESS',
#                'published_at': '2022-12-09T18:17:51.942387+00:00',
#                'revised_at': '2023-04-20T16:43:41.279680+00:00',
#                'schema_version': '3.0.0',
#                'self_reported_ethnicity': [{'label': 'European',
#                                             'ontology_term_id': 'HANCESTRO:0005'}],
#                'sex': [{'label': 'male', 'ontology_term_id': 'PATO:0000384'}],
#                'suspension_type': ['nucleus'],
#                'tissue': [{'label': 'cerebral cortex',
#                            'ontology_term_id': 'UBERON:0000956'}],
#                'title': 'Dissection: Cerebral cortex (Cx) - Occipitotemporal '
#                         '(fusiform) gyrus, temporal part (FuGt) - Temporal '
#                         'area TF',
#                'tombstone': False,
#                'x_approximate_distribution': None},
#               {'assay': [{'label': "10x 3' v3",
#                           'ontology_term_id': 'EFO:0009922'}],
#                'assets': [{'filesize': 887717417,
#                            'filetype': 'H5AD',
#                            'url': 'https://datasets.cellxgene.cziscience.com/40876220-2b88-4b21-8ba5-0eece1114cf5.h5ad'},
#                           {'filesize': 890587977,
#                            'filetype': 'RDS',
#                            'url': 'https://datasets.cellxgene.cziscience.com/40876220-2b88-4b21-8ba5-0eece1114cf5.rds'}],
#                'batch_condition': ['sample_id'],
#                'cell_count': 155025,
#                'cell_type': [{'label': 'astrocyte',
#                               'ontology_term_id': 'CL:0000127'}],
#                'dataset_id': 'f7d003d4-40d5-4de8-858c-a9a8b48fcc67',
#                'dataset_version_id': '40876220-2b88-4b21-8ba5-0eece1114cf5',
#                'development_stage': [{'label': '29-year-old human stage',
#                                       'ontology_term_id': 'HsapDv:0000123'},
#                                      {'label': '42-year-old human stage',
#                                       'ontology_term_id': 'HsapDv:0000136'},
#                                      {'label': '50-year-old human stage',
#                                       'ontology_term_id': 'HsapDv:0000144'},
#                                      {'label': '60-year-old human stage',
#                                       'ontology_term_id': 'HsapDv:0000154'}],
#                'disease': [{'label': 'normal',
#                             'ontology_term_id': 'PATO:0000461'}],
#                'donor_id': ['H18.30.002',
#                             'H19.30.001',
#                             'H19.30.002',
#                             'H18.30.001'],
#                'explorer_url': 'https://cellxgene.cziscience.com/e/40876220-2b88-4b21-8ba5-0eece1114cf5.cxg/',
#                'is_primary_data': [False],
#                'mean_genes_per_cell': 2400.0560038703434,
#                'organism': [{'label': 'Homo sapiens',
#                              'ontology_term_id': 'NCBITaxon:9606'}],
#                'processing_status': 'SUCCESS',
#                'published_at': '2022-12-09T18:17:51.942387+00:00',
#                'revised_at': None,
#                'schema_version': '3.0.0',
#                'self_reported_ethnicity': [{'label': 'European',
#                                             'ontology_term_id': 'HANCESTRO:0005'}],
#                'sex': [{'label': 'female', 'ontology_term_id': 'PATO:0000383'},
#                        {'label': 'male', 'ontology_term_id': 'PATO:0000384'}],
#                'suspension_type': ['nucleus'],
#                'tissue': [{'label': 'cerebellum',
#                            'ontology_term_id': 'UBERON:0002037'},
#                           {'label': 'cerebral cortex',
#                            'ontology_term_id': 'UBERON:0000956'},
#                           {'label': 'cerebral nuclei',
#                            'ontology_term_id': 'UBERON:8440012'},
#                           {'label': 'hippocampal formation',
#                            'ontology_term_id': 'UBERON:0002421'},
#                           {'label': 'hypothalamus',
#                            'ontology_term_id': 'UBERON:0001898'},
#                           {'label': 'midbrain',
#                            'ontology_term_id': 'UBERON:0001891'},
#                           {'label': 'myelencephalon',
#                            'ontology_term_id': 'UBERON:0005290'},
#                           {'label': 'pons',
#                            'ontology_term_id': 'UBERON:0000988'},
#                           {'label': 'spinal cord',
#                            'ontology_term_id': 'UBERON:0002240'},
#                           {'label': 'thalamic complex',
#                            'ontology_term_id': 'UBERON:0010225'}],
#                'title': 'Supercluster: Astrocyte',
#                'tombstone': False,
#                'x_approximate_distribution': None},
#               {'assay': [{'label': "10x 3' v3",
#                           'ontology_term_id': 'EFO:0009922'}],
#                'assets': [{'filesize': 53440089,
#                            'filetype': 'H5AD',
#                            'url': 'https://datasets.cellxgene.cziscience.com/b59402de-a2d3-4071-abb2-7e2213ce58f4.h5ad'},
#                           {'filesize': 48303934,
#                            'filetype': 'RDS',
#                            'url': 'https://datasets.cellxgene.cziscience.com/b59402de-a2d3-4071-abb2-7e2213ce58f4.rds'}],
#                'batch_condition': ['sample_id'],
#                'cell_count': 6877,
#                'cell_type': [{'label': 'astrocyte',
#                               'ontology_term_id': 'CL:0000127'},
#                              {'label': 'central nervous system macrophage',
#                               'ontology_term_id': 'CL:0000878'},
#                              {'label': 'endothelial cell',
#                               'ontology_term_id': 'CL:0000115'},
#                              {'label': 'fibroblast',
#                               'ontology_term_id': 'CL:0000057'},
#                              {'label': 'leukocyte',
#                               'ontology_term_id': 'CL:0000738'},
#                              {'label': 'neuron',
#                               'ontology_term_id': 'CL:0000540'},
#                              {'label': 'oligodendrocyte',
#                               'ontology_term_id': 'CL:0000128'},
#                              {'label': 'oligodendrocyte precursor cell',
#                               'ontology_term_id': 'CL:0002453'},
#                              {'label': 'pericyte',
#                               'ontology_term_id': 'CL:0000669'},
#                              {'label': 'vascular associated smooth muscle cell',
#                               'ontology_term_id': 'CL:0000359'}],
#                'dataset_id': 'f6d9f2ad-5ec7-4d53-b7f0-ceb0e7bcd181',
#                'dataset_version_id': 'b59402de-a2d3-4071-abb2-7e2213ce58f4',
#                'development_stage': [{'label': '42-year-old human stage',
#                                       'ontology_term_id': 'HsapDv:0000136'}],
#                'disease': [{'label': 'normal',
#                             'ontology_term_id': 'PATO:0000461'}],
#                'donor_id': ['H19.30.001'],
#                'explorer_url': 'https://cellxgene.cziscience.com/e/b59402de-a2d3-4071-abb2-7e2213ce58f4.cxg/',
#                'is_primary_data': [True],
#                'mean_genes_per_cell': 2872.177548349571,
#                'organism': [{'label': 'Homo sapiens',
#                              'ontology_term_id': 'NCBITaxon:9606'}],
#                'processing_status': 'SUCCESS',
#                'published_at': '2022-12-09T18:17:51.942387+00:00',
#                'revised_at': '2023-04-20T16:43:41.279680+00:00',
#                'schema_version': '3.0.0',
#                'self_reported_ethnicity': [{'label': 'European',
#                                             'ontology_term_id': 'HANCESTRO:0005'}],
#                'sex': [{'label': 'male', 'ontology_term_id': 'PATO:0000384'}],
#                'suspension_type': ['nucleus'],
#                'tissue': [{'label': 'thalamic complex',
#                            'ontology_term_id': 'UBERON:0010225'}],
#                'title': 'Dissection: Thalamus (THM) - lateral nuclear complex '
#                         'of thalamus (LNC) - ventral posterior lateral nucleus '
#                         '- VPL',
#                'tombstone': False,
#                'x_approximate_distribution': None},
#               {'assay': [{'label': "10x 3' v3",
#                           'ontology_term_id': 'EFO:0009922'}],
#                'assets': [{'filesize': 440469977,
#                            'filetype': 'H5AD',
#                            'url': 'https://datasets.cellxgene.cziscience.com/799dce30-2240-40ff-bf76-3844205c8218.h5ad'},
#                           {'filesize': 492437846,
#                            'filetype': 'RDS',
#                            'url': 'https://datasets.cellxgene.cziscience.com/799dce30-2240-40ff-bf76-3844205c8218.rds'}],
#                'batch_condition': ['sample_id'],
#                'cell_count': 34416,
#                'cell_type': [{'label': 'astrocyte',
#                               'ontology_term_id': 'CL:0000127'},
#                              {'label': 'central nervous system macrophage',
#                               'ontology_term_id': 'CL:0000878'},
#                              {'label': 'endothelial cell',
#                               'ontology_term_id': 'CL:0000115'},
#                              {'label': 'fibroblast',
#                               'ontology_term_id': 'CL:0000057'},
#                              {'label': 'leukocyte',
#                               'ontology_term_id': 'CL:0000738'},
#                              {'label': 'neuron',
#                               'ontology_term_id': 'CL:0000540'},
#                              {'label': 'oligodendrocyte',
#                               'ontology_term_id': 'CL:0000128'},
#                              {'label': 'oligodendrocyte precursor cell',
#                               'ontology_term_id': 'CL:0002453'},
#                              {'label': 'pericyte',
#                               'ontology_term_id': 'CL:0000669'},
#                              {'label': 'vascular associated smooth muscle cell',
#                               'ontology_term_id': 'CL:0000359'}],
#                'dataset_id': 'f5a04dff-d394-4023-8811-65494e8bb11d',
#                'dataset_version_id': '799dce30-2240-40ff-bf76-3844205c8218',
#                'development_stage': [{'label': '29-year-old human stage',
#                                       'ontology_term_id': 'HsapDv:0000123'},
#                                      {'label': '42-year-old human stage',
#                                       'ontology_term_id': 'HsapDv:0000136'},
#                                      {'label': '50-year-old human stage',
#                                       'ontology_term_id': 'HsapDv:0000144'}],
#                'disease': [{'label': 'normal',
#                             'ontology_term_id': 'PATO:0000461'}],
#                'donor_id': ['H19.30.002', 'H18.30.002', 'H19.30.001'],
#                'explorer_url': 'https://cellxgene.cziscience.com/e/799dce30-2240-40ff-bf76-3844205c8218.cxg/',
#                'is_primary_data': [True],
#                'mean_genes_per_cell': 5731.749854718735,
#                'organism': [{'label': 'Homo sapiens',
#                              'ontology_term_id': 'NCBITaxon:9606'}],
#                'processing_status': 'SUCCESS',
#                'published_at': '2022-12-09T18:17:51.942387+00:00',
#                'revised_at': '2023-04-20T16:43:41.279680+00:00',
#                'schema_version': '3.0.0',
#                'self_reported_ethnicity': [{'label': 'European',
#                                             'ontology_term_id': 'HANCESTRO:0005'}],
#                'sex': [{'label': 'male', 'ontology_term_id': 'PATO:0000384'}],
#                'suspension_type': ['nucleus'],
#                'tissue': [{'label': 'cerebral nuclei',
#                            'ontology_term_id': 'UBERON:8440012'}],
#                'title': 'Dissection: Basal nuclei (BN) - Putamen - Pu',
#                'tombstone': False,
#                'x_approximate_distribution': None},
#               {'assay': [{'label': "10x 3' v3",
#                           'ontology_term_id': 'EFO:0009922'}],
#                'assets': [{'filesize': 390744347,
#                            'filetype': 'H5AD',
#                            'url': 'https://datasets.cellxgene.cziscience.com/adf1ed80-d66e-4a5b-b895-c464eb1fc862.h5ad'},
#                           {'filesize': 459472101,
#                            'filetype': 'RDS',
#                            'url': 'https://datasets.cellxgene.cziscience.com/adf1ed80-d66e-4a5b-b895-c464eb1fc862.rds'}],
#                'batch_condition': ['sample_id'],
#                'cell_count': 31230,
#                'cell_type': [{'label': 'astrocyte',
#                               'ontology_term_id': 'CL:0000127'},
#                              {'label': 'central nervous system macrophage',
#                               'ontology_term_id': 'CL:0000878'},
#                              {'label': 'endothelial cell',
#                               'ontology_term_id': 'CL:0000115'},
#                              {'label': 'fibroblast',
#                               'ontology_term_id': 'CL:0000057'},
#                              {'label': 'leukocyte',
#                               'ontology_term_id': 'CL:0000738'},
#                              {'label': 'neuron',
#                               'ontology_term_id': 'CL:0000540'},
#                              {'label': 'oligodendrocyte',
#                               'ontology_term_id': 'CL:0000128'},
#                              {'label': 'oligodendrocyte precursor cell',
#                               'ontology_term_id': 'CL:0002453'},
#                              {'label': 'pericyte',
#                               'ontology_term_id': 'CL:0000669'},
#                              {'label': 'vascular associated smooth muscle cell',
#                               'ontology_term_id': 'CL:0000359'}],
#                'dataset_id': 'f502c312-05dc-4fd4-a762-92a63e92b539',
#                'dataset_version_id': 'adf1ed80-d66e-4a5b-b895-c464eb1fc862',
#                'development_stage': [{'label': '29-year-old human stage',
#                                       'ontology_term_id': 'HsapDv:0000123'},
#                                      {'label': '42-year-old human stage',
#                                       'ontology_term_id': 'HsapDv:0000136'},
#                                      {'label': '50-year-old human stage',
#                                       'ontology_term_id': 'HsapDv:0000144'}],
#                'disease': [{'label': 'normal',
#                             'ontology_term_id': 'PATO:0000461'}],
#                'donor_id': ['H19.30.002', 'H19.30.001', 'H18.30.002'],
#                'explorer_url': 'https://cellxgene.cziscience.com/e/adf1ed80-d66e-4a5b-b895-c464eb1fc862.cxg/',
#                'is_primary_data': [True],
#                'mean_genes_per_cell': 5623.0531219980785,
#                'organism': [{'label': 'Homo sapiens',
#                              'ontology_term_id': 'NCBITaxon:9606'}],
#                'processing_status': 'SUCCESS',
#                'published_at': '2022-12-09T18:17:51.942387+00:00',
#                'revised_at': '2023-04-20T16:43:41.279680+00:00',
#                'schema_version': '3.0.0',
#                'self_reported_ethnicity': [{'label': 'European',
#                                             'ontology_term_id': 'HANCESTRO:0005'}],
#                'sex': [{'label': 'male', 'ontology_term_id': 'PATO:0000384'}],
#                'suspension_type': ['nucleus'],
#                'tissue': [{'label': 'cerebral cortex',
#                            'ontology_term_id': 'UBERON:0000956'}],
#                'title': 'Dissection: Paleocortex (PalCx) - Anterior Olfactory '
#                         'Nucleus - AON',
#                'tombstone': False,
#                'x_approximate_distribution': None},
#               {'assay': [{'label': "10x 3' v3",
#                           'ontology_term_id': 'EFO:0009922'}],
#                'assets': [{'filesize': 229638501,
#                            'filetype': 'H5AD',
#                            'url': 'https://datasets.cellxgene.cziscience.com/48f7f78f-f3c1-47dd-8d04-1610e49d804f.h5ad'},
#                           {'filesize': 245288039,
#                            'filetype': 'RDS',
#                            'url': 'https://datasets.cellxgene.cziscience.com/48f7f78f-f3c1-47dd-8d04-1610e49d804f.rds'}],
#                'batch_condition': ['sample_id'],
#                'cell_count': 24155,
#                'cell_type': [{'label': 'Bergmann glial cell',
#                               'ontology_term_id': 'CL:0000644'},
#                              {'label': 'astrocyte',
#                               'ontology_term_id': 'CL:0000127'},
#                              {'label': 'central nervous system macrophage',
#                               'ontology_term_id': 'CL:0000878'},
#                              {'label': 'endothelial cell',
#                               'ontology_term_id': 'CL:0000115'},
#                              {'label': 'ependymal cell',
#                               'ontology_term_id': 'CL:0000065'},
#                              {'label': 'fibroblast',
#                               'ontology_term_id': 'CL:0000057'},
#                              {'label': 'leukocyte',
#                               'ontology_term_id': 'CL:0000738'},
#                              {'label': 'neuron',
#                               'ontology_term_id': 'CL:0000540'},
#                              {'label': 'oligodendrocyte',
#                               'ontology_term_id': 'CL:0000128'},
#                              {'label': 'oligodendrocyte precursor cell',
#                               'ontology_term_id': 'CL:0002453'},
#                              {'label': 'pericyte',
#                               'ontology_term_id': 'CL:0000669'},
#                              {'label': 'vascular associated smooth muscle cell',
#                               'ontology_term_id': 'CL:0000359'}],
#                'dataset_id': 'f3565fda-499a-4d20-bd92-563c09954c42',
#                'dataset_version_id': '48f7f78f-f3c1-47dd-8d04-1610e49d804f',
#                'development_stage': [{'label': '29-year-old human stage',
#                                       'ontology_term_id': 'HsapDv:0000123'},
#                                      {'label': '42-year-old human stage',
#                                       'ontology_term_id': 'HsapDv:0000136'},
#                                      {'label': '50-year-old human stage',
#                                       'ontology_term_id': 'HsapDv:0000144'}],
#                'disease': [{'label': 'normal',
#                             'ontology_term_id': 'PATO:0000461'}],
#                'donor_id': ['H19.30.001', 'H18.30.002', 'H19.30.002'],
#                'explorer_url': 'https://cellxgene.cziscience.com/e/48f7f78f-f3c1-47dd-8d04-1610e49d804f.cxg/',
#                'is_primary_data': [True],
#                'mean_genes_per_cell': 4142.2287311115715,
#                'organism': [{'label': 'Homo sapiens',
#                              'ontology_term_id': 'NCBITaxon:9606'}],
#                'processing_status': 'SUCCESS',
#                'published_at': '2022-12-09T18:17:51.942387+00:00',
#                'revised_at': '2023-04-20T16:43:41.279680+00:00',
#                'schema_version': '3.0.0',
#                'self_reported_ethnicity': [{'label': 'European',
#                                             'ontology_term_id': 'HANCESTRO:0005'}],
#                'sex': [{'label': 'male', 'ontology_term_id': 'PATO:0000384'}],
#                'suspension_type': ['nucleus'],
#                'tissue': [{'label': 'pons',
#                            'ontology_term_id': 'UBERON:0000988'}],
#                'title': 'Dissection: Pons (Pn) - Pontine reticular formation '
#                         '(PnRF) - parabrachial nuclei - PB',
#                'tombstone': False,
#                'x_approximate_distribution': None},
#               {'assay': [{'label': "10x 3' v3",
#                           'ontology_term_id': 'EFO:0009922'}],
#                'assets': [{'filesize': 1415540494,
#                            'filetype': 'H5AD',
#                            'url': 'https://datasets.cellxgene.cziscience.com/b6ad0339-ffd3-4edc-8dfe-5f8c46a9378c.h5ad'},
#                           {'filesize': 1567165363,
#                            'filetype': 'RDS',
#                            'url': 'https://datasets.cellxgene.cziscience.com/b6ad0339-ffd3-4edc-8dfe-5f8c46a9378c.rds'}],
#                'batch_condition': ['sample_id'],
#                'cell_count': 116576,
#                'cell_type': [{'label': 'astrocyte',
#                               'ontology_term_id': 'CL:0000127'},
#                              {'label': 'central nervous system macrophage',
#                               'ontology_term_id': 'CL:0000878'},
#                              {'label': 'choroid plexus epithelial cell',
#                               'ontology_term_id': 'CL:0000706'},
#                              {'label': 'endothelial cell',
#                               'ontology_term_id': 'CL:0000115'},
#                              {'label': 'fibroblast',
#                               'ontology_term_id': 'CL:0000057'},
#                              {'label': 'leukocyte',
#                               'ontology_term_id': 'CL:0000738'},
#                              {'label': 'neuron',
#                               'ontology_term_id': 'CL:0000540'},
#                              {'label': 'oligodendrocyte',
#                               'ontology_term_id': 'CL:0000128'},
#                              {'label': 'oligodendrocyte precursor cell',
#                               'ontology_term_id': 'CL:0002453'},
#                              {'label': 'pericyte',
#                               'ontology_term_id': 'CL:0000669'},
#                              {'label': 'vascular associated smooth muscle cell',
#                               'ontology_term_id': 'CL:0000359'}],
#                'dataset_id': 'f32c2c13-bb1a-4ffd-a457-60b64ecfa4cb',
#                'dataset_version_id': 'b6ad0339-ffd3-4edc-8dfe-5f8c46a9378c',
#                'development_stage': [{'label': '29-year-old human stage',
#                                       'ontology_term_id': 'HsapDv:0000123'},
#                                      {'label': '42-year-old human stage',
#                                       'ontology_term_id': 'HsapDv:0000136'},
#                                      {'label': '50-year-old human stage',
#                                       'ontology_term_id': 'HsapDv:0000144'},
#                                      {'label': '60-year-old human stage',
#                                       'ontology_term_id': 'HsapDv:0000154'}],
#                'disease': [{'label': 'normal',
#                             'ontology_term_id': 'PATO:0000461'}],
#                'donor_id': ['H19.30.001',
#                             'H18.30.001',
#                             'H18.30.002',
#                             'H19.30.002'],
#                'explorer_url': 'https://cellxgene.cziscience.com/e/b6ad0339-ffd3-4edc-8dfe-5f8c46a9378c.cxg/',
#                'is_primary_data': [True],
#                'mean_genes_per_cell': 5579.966502539116,
#                'organism': [{'label': 'Homo sapiens',
#                              'ontology_term_id': 'NCBITaxon:9606'}],
#                'processing_status': 'SUCCESS',
#                'published_at': '2022-12-09T18:17:51.942387+00:00',
#                'revised_at': '2023-04-20T16:43:41.279680+00:00',
#                'schema_version': '3.0.0',
#                'self_reported_ethnicity': [{'label': 'European',
#                                             'ontology_term_id': 'HANCESTRO:0005'}],
#                'sex': [{'label': 'female', 'ontology_term_id': 'PATO:0000383'},
#                        {'label': 'male', 'ontology_term_id': 'PATO:0000384'}],
#                'suspension_type': ['nucleus'],
#                'tissue': [{'label': 'cerebral cortex',
#                            'ontology_term_id': 'UBERON:0000956'}],
#                'title': 'Dissection: Cerebral cortex (Cx) - Precentral gyrus '
#                         '(PrCG) - Primary motor cortex - M1C',
#                'tombstone': False,
#                'x_approximate_distribution': None},
#               {'assay': [{'label': "10x 3' v3",
#                           'ontology_term_id': 'EFO:0009922'}],
#                'assets': [{'filesize': 205895285,
#                            'filetype': 'H5AD',
#                            'url': 'https://datasets.cellxgene.cziscience.com/e864396a-5679-46f2-b701-860d11d7b261.h5ad'},
#                           {'filesize': 218549513,
#                            'filetype': 'RDS',
# ...
#                'batch_condition': ['sample_id'],
#                'cell_count': 137162,
#                'cell_type': [{'label': 'neuron',
#                               'ontology_term_id': 'CL:0000540'}],
#                'dataset_id': '04a23820-ffa8-4be5-9f65-64db15631d1e',
#                'dataset_version_id': 'd84eaf4e-1d69-4390-8d11-ed369e85d514',
#                'development_stage': [{'label': '29-year-old human stage',
#                                       'ontology_term_id': 'HsapDv:0000123'},
#                                      {'label': '42-year-old human stage',
#                                       'ontology_term_id': 'HsapDv:0000136'},
#                                      {'label': '50-year-old human stage',
#                                       'ontology_term_id': 'HsapDv:0000144'},
#                                      {'label': '60-year-old human stage',
#                                       'ontology_term_id': 'HsapDv:0000154'}],
#                'disease': [{'label': 'normal',
#                             'ontology_term_id': 'PATO:0000461'}],
#                'donor_id': ['H19.30.002',
#                             'H18.30.002',
#                             'H19.30.001',
#                             'H18.30.001'],
#                'explorer_url': 'https://cellxgene.cziscience.com/e/d84eaf4e-1d69-4390-8d11-ed369e85d514.cxg/',
#                'is_primary_data': [False],
#                'mean_genes_per_cell': 2150.4101062976624,
#                'organism': [{'label': 'Homo sapiens',
#                              'ontology_term_id': 'NCBITaxon:9606'}],
#                'processing_status': 'PENDING',
#                'published_at': '2022-12-09T18:17:51.942387+00:00',
#                'revised_at': None,
#                'schema_version': '3.0.0',
#                'self_reported_ethnicity': [{'label': 'European',
#                                             'ontology_term_id': 'HANCESTRO:0005'}],
#                'sex': [{'label': 'female', 'ontology_term_id': 'PATO:0000383'},
#                        {'label': 'male', 'ontology_term_id': 'PATO:0000384'}],
#                'suspension_type': ['nucleus'],
#                'tissue': [{'label': 'cerebellum',
#                            'ontology_term_id': 'UBERON:0002037'},
#                           {'label': 'cerebral cortex',
#                            'ontology_term_id': 'UBERON:0000956'},
#                           {'label': 'cerebral nuclei',
#                            'ontology_term_id': 'UBERON:8440012'},
#                           {'label': 'hippocampal formation',
#                            'ontology_term_id': 'UBERON:0002421'},
#                           {'label': 'hypothalamus',
#                            'ontology_term_id': 'UBERON:0001898'},
#                           {'label': 'midbrain',
#                            'ontology_term_id': 'UBERON:0001891'},
#                           {'label': 'myelencephalon',
#                            'ontology_term_id': 'UBERON:0005290'},
#                           {'label': 'pons',
#                            'ontology_term_id': 'UBERON:0000988'},
#                           {'label': 'spinal cord',
#                            'ontology_term_id': 'UBERON:0002240'},
#                           {'label': 'thalamic complex',
#                            'ontology_term_id': 'UBERON:0010225'}],
#                'title': 'Supercluster: Upper rhombic lip',
#                'tombstone': False,
#                'x_approximate_distribution': None},
#               {'assay': [{'label': "10x 3' v3",
#                           'ontology_term_id': 'EFO:0009922'}],
#                'assets': [{'filesize': 166390300,
#                            'filetype': 'H5AD',
#                            'url': 'https://datasets.cellxgene.cziscience.com/56d3cdc8-5fca-4e54-bbbc-0ecf38c14505.h5ad'},
#                           {'filesize': 173007776,
#                            'filetype': 'RDS',
#                            'url': 'https://datasets.cellxgene.cziscience.com/56d3cdc8-5fca-4e54-bbbc-0ecf38c14505.rds'}],
#                'batch_condition': ['sample_id'],
#                'cell_count': 20027,
#                'cell_type': [{'label': 'astrocyte',
#                               'ontology_term_id': 'CL:0000127'},
#                              {'label': 'central nervous system macrophage',
#                               'ontology_term_id': 'CL:0000878'},
#                              {'label': 'endothelial cell',
#                               'ontology_term_id': 'CL:0000115'},
#                              {'label': 'ependymal cell',
#                               'ontology_term_id': 'CL:0000065'},
#                              {'label': 'fibroblast',
#                               'ontology_term_id': 'CL:0000057'},
#                              {'label': 'leukocyte',
#                               'ontology_term_id': 'CL:0000738'},
#                              {'label': 'neuron',
#                               'ontology_term_id': 'CL:0000540'},
#                              {'label': 'oligodendrocyte',
#                               'ontology_term_id': 'CL:0000128'},
#                              {'label': 'oligodendrocyte precursor cell',
#                               'ontology_term_id': 'CL:0002453'},
#                              {'label': 'pericyte',
#                               'ontology_term_id': 'CL:0000669'},
#                              {'label': 'vascular associated smooth muscle cell',
#                               'ontology_term_id': 'CL:0000359'}],
#                'dataset_id': '03d38670-1444-4001-bc53-9936e61d9b20',
#                'dataset_version_id': '56d3cdc8-5fca-4e54-bbbc-0ecf38c14505',
#                'development_stage': [{'label': '29-year-old human stage',
#                                       'ontology_term_id': 'HsapDv:0000123'},
#                                      {'label': '42-year-old human stage',
#                                       'ontology_term_id': 'HsapDv:0000136'}],
#                'disease': [{'label': 'normal',
#                             'ontology_term_id': 'PATO:0000461'}],
#                'donor_id': ['H19.30.002', 'H19.30.001'],
#                'explorer_url': 'https://cellxgene.cziscience.com/e/56d3cdc8-5fca-4e54-bbbc-0ecf38c14505.cxg/',
#                'is_primary_data': [True],
#                'mean_genes_per_cell': 3499.4100464373096,
#                'organism': [{'label': 'Homo sapiens',
#                              'ontology_term_id': 'NCBITaxon:9606'}],
#                'processing_status': 'SUCCESS',
#                'published_at': '2022-12-09T18:17:51.942387+00:00',
#                'revised_at': '2023-04-20T16:43:41.279680+00:00',
#                'schema_version': '3.0.0',
#                'self_reported_ethnicity': [{'label': 'European',
#                                             'ontology_term_id': 'HANCESTRO:0005'}],
#                'sex': [{'label': 'male', 'ontology_term_id': 'PATO:0000384'}],
#                'suspension_type': ['nucleus'],
#                'tissue': [{'label': 'hypothalamus',
#                            'ontology_term_id': 'UBERON:0001898'}],
#                'title': 'Dissection: Hypothalamus (HTH) - preoptic region of '
#                         'HTH - HTHpo (medial preoptic nucleus, MPN) - '
#                         'supraoptic region of HTH - HTHso (paraventricular '
#                         'nucleus, PV)',
#                'tombstone': False,
#                'x_approximate_distribution': None},
#               {'assets': [],
#                'dataset_id': '0325478a-9b52-45b5-b40a-2e2ab0d72eb1',
#                'dataset_version_id': '2f426a72-1013-4dad-990e-0dcfa64b056f',
#                'explorer_url': 'https://cellxgene.cziscience.com/e/2f426a72-1013-4dad-990e-0dcfa64b056f.cxg/',
#                'processing_status': 'PENDING',
#                'published_at': '2022-12-09T18:17:51.942387+00:00',
#                'revised_at': None,
#                'title': None,
#                'tombstone': False},
#               {'assay': [{'label': "10x 3' v3",
#                           'ontology_term_id': 'EFO:0009922'}],
#                'assets': [{'filesize': 131643578,
#                            'filetype': 'H5AD',
#                            'url': 'https://datasets.cellxgene.cziscience.com/c00f3842-a3fa-4623-878f-526cb04782a1.h5ad'},
#                           {'filesize': 139977973,
#                            'filetype': 'RDS',
#                            'url': 'https://datasets.cellxgene.cziscience.com/c00f3842-a3fa-4623-878f-526cb04782a1.rds'}],
#                'batch_condition': ['sample_id'],
#                'cell_count': 10099,
#                'cell_type': [{'label': 'astrocyte',
#                               'ontology_term_id': 'CL:0000127'},
#                              {'label': 'central nervous system macrophage',
#                               'ontology_term_id': 'CL:0000878'},
#                              {'label': 'endothelial cell',
#                               'ontology_term_id': 'CL:0000115'},
#                              {'label': 'ependymal cell',
#                               'ontology_term_id': 'CL:0000065'},
#                              {'label': 'fibroblast',
#                               'ontology_term_id': 'CL:0000057'},
#                              {'label': 'leukocyte',
#                               'ontology_term_id': 'CL:0000738'},
#                              {'label': 'neuron',
#                               'ontology_term_id': 'CL:0000540'},
#                              {'label': 'oligodendrocyte',
#                               'ontology_term_id': 'CL:0000128'},
#                              {'label': 'oligodendrocyte precursor cell',
#                               'ontology_term_id': 'CL:0002453'},
#                              {'label': 'pericyte',
#                               'ontology_term_id': 'CL:0000669'},
#                              {'label': 'vascular associated smooth muscle cell',
#                               'ontology_term_id': 'CL:0000359'}],
#                'dataset_id': '00476f9f-ebc1-4b72-b541-32f912ce36ea',
#                'dataset_version_id': 'c00f3842-a3fa-4623-878f-526cb04782a1',
#                'development_stage': [{'label': '42-year-old human stage',
#                                       'ontology_term_id': 'HsapDv:0000136'}],
#                'disease': [{'label': 'normal',
#                             'ontology_term_id': 'PATO:0000461'}],
#                'donor_id': ['H19.30.001'],
#                'explorer_url': 'https://cellxgene.cziscience.com/e/c00f3842-a3fa-4623-878f-526cb04782a1.cxg/',
#                'is_primary_data': [True],
#                'mean_genes_per_cell': 5572.776710565403,
#                'organism': [{'label': 'Homo sapiens',
#                              'ontology_term_id': 'NCBITaxon:9606'}],
#                'processing_status': 'SUCCESS',
#                'published_at': '2022-12-09T18:17:51.942387+00:00',
#                'revised_at': '2023-04-20T16:43:41.279680+00:00',
#                'schema_version': '3.0.0',
#                'self_reported_ethnicity': [{'label': 'European',
#                                             'ontology_term_id': 'HANCESTRO:0005'}],
#                'sex': [{'label': 'male', 'ontology_term_id': 'PATO:0000384'}],
#                'suspension_type': ['nucleus'],
#                'tissue': [{'label': 'hypothalamus',
#                            'ontology_term_id': 'UBERON:0001898'}],
#                'title': 'Dissection: Hypothalamus (HTH) - mammillary region of '
#                         'HTH (HTHma)',
#                'tombstone': False,
#                'x_approximate_distribution': None}],
#  'description': 'The human brain directs a wide range of complex behaviors '
#                 'ranging from fine motor skills to abstract intelligence and '
#                 'emotion. However, the diversity of cell types that support '
#                 'these skills has not been fully described. Here we used '
#                 'high-throughput single-nucleus RNA sequencing to '
#                 'systematically survey cells across the entire adult human '
#                 'brain in three postmortem donors. We sampled over three '
#                 'million nuclei from approximately 100 dissections across the '
#                 'forebrain, midbrain, and hindbrain. Our analysis identified '
#                 '461 clusters and 3313 subclusters organized largely according '
#                 'to developmental origins. We found area-specific cortical '
#                 'neurons, as well as an unexpectedly high diversity of '
#                 'midbrain and hindbrain neurons. Astrocytes also exhibited '
#                 'regional diversity at multiple scales, comprising subtypes '
#                 'specific to the telencephalon and to more precise anatomical '
#                 'locations. Oligodendrocyte precursors comprised two distinct '
#                 'major types specific to the telencephalon and to the rest of '
#                 'the brain. Together, these findings demonstrate the unique '
#                 'cellular composition of the telencephalon with respect to all '
#                 'major brain cell types. As the first single-cell '
#                 'transcriptomic census of the entire human brain, we provide a '
#                 'resource for understanding the molecular diversity of the '
#                 'human brain in health and disease.',
#  'doi': '10.1101/2022.10.12.511898',
#  'links': [{'link_name': '',
#             'link_type': 'RAW_DATA',
#             'link_url': 'http://data.nemoarchive.org/biccn/grant/u01_lein/linnarsson/transcriptome/sncell/10x_v3/human/raw/'},
#            {'link_name': '',
#             'link_type': 'OTHER',
#             'link_url': 'https://github.com/linnarsson-lab/adult-human-brain'},
#            {'link_name': '',
#             'link_type': 'OTHER',
#             'link_url': 'https://github.com/linnarsson-lab/auto-annotation-ah'}],
#  'name': 'Transcriptomic diversity of cell types across the adult human brain',
#  'processing_status': 'PENDING',
#  'published_at': '2022-12-09T18:17:51.942387+00:00',
#  'publisher_metadata': {'authors': [{'family': 'Siletti', 'given': 'Kimberly'},
#                                     {'family': 'Hodge', 'given': 'Rebecca'},
#                                     {'family': 'Mossi Albiach',
#                                      'given': 'Alejandro'},
#                                     {'family': 'Hu', 'given': 'Lijuan'},
#                                     {'family': 'Lee', 'given': 'Ka Wai'},
#                                     {'family': 'Lönnerberg', 'given': 'Peter'},
#                                     {'family': 'Bakken', 'given': 'Trygve'},
#                                     {'family': 'Ding', 'given': 'Song-Lin'},
#                                     {'family': 'Clark', 'given': 'Michael'},
#                                     {'family': 'Casper', 'given': 'Tamara'},
#                                     {'family': 'Dee', 'given': 'Nick'},
#                                     {'family': 'Gloe', 'given': 'Jessica'},
#                                     {'family': 'Keene', 'given': 'C. Dirk'},
#                                     {'family': 'Nyhus', 'given': 'Julie'},
#                                     {'family': 'Tung', 'given': 'Herman'},
#                                     {'family': 'Yanny', 'given': 'Anna Marie'},
#                                     {'family': 'Arenas', 'given': 'Ernest'},
#                                     {'family': 'Lein', 'given': 'Ed S.'},
#                                     {'family': 'Linnarsson', 'given': 'Sten'}],
#                         'is_preprint': True,
#                         'journal': 'bioRxiv',
#                         'published_at': 1665705600.0,
#                         'published_day': 14,
#                         'published_month': 10,
#                         'published_year': 2022},
#  'revised_at': '2023-04-20T16:43:41.279680+00:00',
#  'revising_in': None,
#  'revision_of': '283d65eb-dd53-496d-adb7-7570c7caa443',
#  'visibility': 'PRIVATE'}

# %%
dataset = [i for i in collection["datasets"] if i["title"] == "Neurons"]
dataset[0]["dataset_id"]
# Out:
# '8e10f1c4-8e98-41e5-b65f-8cd89a887122'
