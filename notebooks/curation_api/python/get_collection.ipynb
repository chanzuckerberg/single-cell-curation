# %% [markdown]
# # Fetch a Collection with full Dataset metadata

# %% [markdown]
# The script in this notebook fetches full Collection metadata for a given Collection uuid.
#
# In order to fetch private Collections with this script, you must have a Curation API key (obtained from upper-righthand dropdown in the Data Portal UI after logging in). You may fetch public Collections without an API key / access token.

# %% [markdown]
# #### <font color='#bc00b0'>Please fill in the required values:</font>

# %% [markdown]
# <font color='#bc00b0'>(Required) Provide the path to your api key file</font>

# %%
api_key_file_path = "path/to/api-key-file"

# %% [markdown]
# <font color='#bc00b0'>(Required) Enter the uuid of the Collection you want to fetch</font>
#
# _The Collection uuid can be found by looking at the url path in the address bar
# when viewing your Collection in the UI of the Data Portal website:_ `collections/{collection_uuid}`.

# %%
collection_uuid = "01234567-89ab-cdef-0123-456789abcdef"

# %% [markdown]
# ### Import dependencies

# %%
from src.utils.config import set_api_access_config
from src.utils.logger import set_log_level  # can set_log_level("ERROR") for less logging; default is "INFO"
from src.collection import get_collection

# %% [markdown]
# ### Set url and access token env vars

# %%
set_api_access_config(api_key_file_path)

# %% [markdown]
# ### Fetch Collection

# %%
res = get_collection(collection_uuid)
