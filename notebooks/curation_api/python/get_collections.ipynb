# %% [markdown]
# # Fetch Collections index with Dataset previews

# %% [markdown]
# The script in this notebook fetches...
# - all public Collections (with query param `visibility=PUBLIC` or not set).
#
# or
# - all access-allowed private Collections (with query param `visibility=PRIVATE`; access token required).
#
# In order to fetch private Collections with this script, you must have a Curation API key (obtained from upper-righthand dropdown in the Data Portal UI after logging in). You may fetch public Collections without an API key / access token.

# %% [markdown]
# #### <font color='#bc00b0'>Please fill in the required values:</font>

# %% [markdown]
# <font color='#bc00b0'>(Required) Provide the path to your api key file</font>

# %%
api_key_file_path = "path/to/api-key-file"
api_key_file_path = "../../../dev_key"

# %% [markdown]
# ### Import dependencies

# %%
from src.utils.config import set_api_urls, set_access_token
from src.utils.logger import set_log_level  # can set_log_level("ERROR") for less logging; default is "INFO"
from src.collection import get_collections

# %% [markdown]
# ### Set url and access token env vars

# %%
set_api_urls(env="dev")
set_access_token(api_key_file_path)
# Out:
# Set 'site_url' env var to https://cellxgene.dev.single-cell.czi.technology
# Set 'api_url_base' env var to https://api.cellxgene.dev.single-cell.czi.technology
# Successfully set 'access_token' env var!

# %% [markdown]
# ### Fetch Collection

# %%
collections = get_collections()
print(collections)
# Out:
# [{'access_type': 'WRITE', 'collection_url': 'https://cellxgene.dev.single-cell.czi.technology/collections/66bff4a1-3726-40ce-a887-46f3ec34ace1', 'contact_email': 'person@random.com', 'contact_name': 'Doctor Who', 'created_at': 1647567373.64757, 'curator_name': 'John Smith', 'datasets': [{'assay': [{'label': "10x 3' v2", 'ontology_term_id': 'EFO:0009899'}, {'label': "10x 3' v3", 'ontology_term_id': 'EFO:0009922'}, {'label': "10x 3' v3 (sci-plex)", 'ontology_term_id': 'EFO:0009922 (sci-plex)'}], 'curator_tag': None, 'disease': [{'label': 'COVID-19', 'ontology_term_id': 'MONDO:0100096'}, {'label': 'normal', 'ontology_term_id': 'PATO:0000461'}], 'id': 'bc098989-ae84-4e6b-8611-d94db5a1601a', 'organism': [{'label': 'Callithrix jacchus', 'ontology_term_id': 'NCBITaxon:9483'}, {'label': 'Homo sapiens', 'ontology_term_id': 'NCBITaxon:9606'}, {'label': 'Mus musculus', 'ontology_term_id': 'NCBITaxon:10090'}], 'tissue': [{'label': 'brain (organoid)', 'ontology_term_id': 'UBERON:0000955 (organoid)'}, {'label': 'epithelial cell', 'ontology_term_id': 'CL:0000066'}, {'label': 'fibroblast (cell culture)', 'ontology_term_id': 'CL:0000057 (cell culture)'}, {'label': 'heart left ventricle', 'ontology_term_id': 'UBERON:0002084'}, {'label': 'heart right ventricle', 'ontology_term_id': 'UBERON:0002080'}, {'label': 'kidney', 'ontology_term_id': 'UBERON:0002113'}], 'tombstone': True}], 'description': 'These are different words', 'id': '66bff4a1-3726-40ce-a887-46f3ec34ace1', 'links': [], 'name': 'lots of cells', 'processing_status': None, 'published_at': 1647567622.72256, 'publisher_metadata': None, 'revised_at': None, 'revision_of': None, 'tombstone': True, 'visibility': 'PUBLIC'}, {'access_type': 'WRITE', 'collection_url': 'https://cellxgene.dev.single-cell.czi.technology/collections/b67b6c4c-a6b9-43ca-bcae-a7388d0bd192', 'contact_email': 'lisbon@gmail.com', 'contact_name': 'Madrid Sparkle', 'created_at': 1648755907.540034, 'curator_name': '', 'datasets': [{'assay': [{'label': "10x 3' v2", 'ontology_term_id': 'EFO:0009899'}, {'label': "10x 3' v3", 'ontology_term_id': 'EFO:0009922'}, {'label': "10x 3' v3 (sci-plex)", 'ontology_term_id': 'EFO:0009922 (sci-plex)'}], 'curator_tag': None, 'disease': [{'label': 'COVID-19', 'ontology_term_id': 'MONDO:0100096'}, {'label': 'normal', 'ontology_term_id': 'PATO:0000461'}], 'id': '187ad4a7-a306-4a9c-937b-29498630396e', 'organism': [{'label': 'Callithrix jacchus', 'ontology_term_id': 'NCBITaxon:9483'}, {'label': 'Homo sapiens', 'ontology_term_id': 'NCBITaxon:9606'}, {'label': 'Mus musculus', 'ontology_term_id': 'NCBITaxon:10090'}], 'tissue': [{'label': 'brain (organoid)', 'ontology_term_id': 'UBERON:0000955 (organoid)'}, {'label': 'epithelial cell', 'ontology_term_id': 'CL:0000066'}, {'label': 'fibroblast (cell culture)', 'ontology_term_id': 'CL:0000057 (cell culture)'}, {'label': 'heart left ventricle', 'ontology_term_id': 'UBERON:0002084'}, {'label': 'heart right ventricle', 'ontology_term_id': 'UBERON:0002080'}, {'label': 'kidney', 'ontology_term_id': 'UBERON:0002113'}], 'tombstone': True}], 'description': 'Well here are some words', 'id': 'b67b6c4c-a6b9-43ca-bcae-a7388d0bd192', 'links': [], 'name': '1648756485899', 'processing_status': None, 'published_at': 1648756159.806527, 'publisher_metadata': None, 'revised_at': 1648756416.838318, 'revision_of': None, 'tombstone': True, 'visibility': 'PUBLIC'}, {'access_type': 'WRITE', 'collection_url': 'https://cellxgene.dev.single-cell.czi.technology/collections/0d26b45f-ff17-44e8-a158-6e31e3428e0c', 'contact_email': 'person@random.com', 'contact_name': 'Doctor Who', 'created_at': 1650427853.519975, 'curator_name': 'John Smith', 'datasets': [{'assay': [{'label': "10x 3' v2", 'ontology_term_id': 'EFO:0009899'}, {'label': "10x 3' v3", 'ontology_term_id': 'EFO:0009922'}, {'label': "10x 3' v3 (sci-plex)", 'ontology_term_id': 'EFO:0009922 (sci-plex)'}], 'curator_tag': None, 'disease': [{'label': 'COVID-19', 'ontology_term_id': 'MONDO:0100096'}, {'label': 'normal', 'ontology_ ...
